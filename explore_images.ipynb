# %%
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pylab as pl
from data import load_train_data, load_test_data
% matplotlib inline

# %%
imgs_train, imgs_mask_train, subjects = load_train_data()

# %%
i = 1199

plt.figure(figsize=(12,6))
pl.subplot(121)
pl.imshow(imgs_train[i], cmap=cm.gray)
pl.subplot(122)
pl.imshow(imgs_train[i], cmap=cm.gray)
my_cmap = cm.OrRd
my_cmap.set_under(alpha=0)
pl.imshow(imgs_mask_train[i], cmap=my_cmap, clim=[0.9, 1])
plt.show()

# %%
imgs_mask_train.shape
# Out:
# (5635, 420, 580)

# %%
np.argsort(subjects)
# Out:
# array([1199, 1287, 1286, ..., 4826, 4854, 4914], dtype=int64)

# %%
import os
images = list(filter((lambda image: 'mask' not in image), os.listdir('raw_images/train')))
